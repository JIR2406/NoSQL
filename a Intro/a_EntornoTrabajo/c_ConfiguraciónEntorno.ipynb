# %% [markdown]
# <p style="text-align:center">
#     <a href="http://www.ittoluca.edu.mx" target="_blank">
#     <img src="figures/escudoITTol.png" width="100" align="right" />
#     </a>
# </p>
#
# # NOSql Data Bases
#
# ## Working enviroment configuration
#
# ### Content
#
# <div class="alert alert-block alert-info" style="margin-top: 10px">
#     <ol>
#         <li> <a href='#terminal'>Terminal</a></li>
#         <li> <a href='#miniconda'>Miniconda (On-Premises)</a></li>
#         <li> <a href='#nb'>Jupyter Notebooks</a></li>
#         <li> <a href='#md'>Markdown</a></li>
#         <li> <a href='#py'>Python programming</a></li>
#     </ol>
# </div>

# %% [markdown]
# <a id ="terminal"></a>
#
# ## Terminal
#
# **The terminal** is a text-based interface that allows users to interact with their computer's operating system by typing commands. It provides direct access to the system’s shell, which interprets and executes commands. The terminal is commonly used for tasks like navigating the file system, running scripts, managing processes, and configuring system settings.
#
# Key Features:
# * **Command-Line Interface (CLI):** Unlike graphical user interfaces (GUIs), the terminal operates entirely through text commands.
#
#
# * **Shell Integration:** The terminal runs a shell (e.g., Bash, Zsh, PowerShell) that processes user commands.
#
#
# * **Automation:** Commands can be scripted for automation using shell scripts.
#
#
# * **Remote Access:** It can be used to connect to remote servers via SSH.
#
#
# * **Efficiency:** Many tasks can be performed faster with commands compared to GUI-based interactions.
#
#
#
# The following shells depend on the operating system:
#
# * **Windows, (Linux, Mac):** [PowerShell][PS], [cheatsheet][CSHT]
#
#
# * **Mac / Linux:** [Bash][BSH], [zsh][ZSH]
#
# > **In Jupyter Notebooks, we can execute a shell command by placing an exclamation mark (!) before the command.**
# >
# > Ejemplo:
# > * ```pwd``` The pwd (print working directory) command displays the path of the current working directory in the terminal.
#
# [PS]:<https://learn.microsoft.com/es-es/powershell/scripting/overview?view=powershell-7.5>
# [BSH]:<https://en.wikipedia.org/wiki/Bash_(Unix_shell)#Documentation>
# [ZSH]:<https://ohmyz.sh>
# [CSHT]:<https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://download.microsoft.com/download/2/1/2/2122f0b9-0ee6-4e6d-bfd6-f9dcd27c07f9/ws12_quickref_download_files/powershell_langref_v3.pdf&ved=2ahUKEwiJ5Yj6_beLAxWmHkQIHe_fAjkQFnoECBgQAQ&usg=AOvVaw2fkmTgC31xYh8uGe4qeoup>

# %%
# !pwd
# Out:
# /Users/ralf/Documents/Development/NoSQL/a_ConfiguracionEntorno

# %% [markdown]
# <a id="miniconda"></a>
# # Miniconda
#
# **Referencias:**
#
# 1. [Requirements, installation][REQ]
#
#
# 2. ```> conda``` [commands][COMDS]
#
#
# 3. [CheatSheet:][CSHT] The conda cheatsheet contains the most important information about using conda, such as basic commands for creating and managing environments, installing packages, and importing and exporting environments.
#
#
# ### Setting up the working python-environment
#
# 1. To create an environment called ```nosql``` with which we will work in the course.
# ```terminal
# > conda create --name nosql -y
# ```
#
# 2. Activate the ```nosql``` environment
# ```terminal
# > conda activate nosql
# ```
#
# * To install additional libraries
# ```terminal
# > conda install pandas matplotlib numpy -y
# ```
#
# * To delete an environment called ```nosql```
# ```terminal
# > conda env remove -n nosql
# ```
#
# * To deactivate an environment
# ```terminal
# > conda deactivate
# ```
#
# ### Installing *Jupyter Notebooks* and adding the ```nosql``` kernel
#
# * Install *Jupyter Notebooks*
# ```terminal
# > conda install jupyter -y
# ```
#
# * Show the list of installed kernels in Jupyter Notebooks
# ```terminal
# > jupyter kernelspec list
# ```
#
# * We install the ```ipykernel``` library, which allows adding kernels to Jupyter Notebooks
# ```terminal
# > conda install ipykernel -y
# ```
#
# * We register the ```nosql``` environment (kernel) in Jupyter Notebooks.
# ```terminal
# > python -m ipykernel install --user --name=nosql
# ```
#
# * We verify that the 'nosql' kernel can be changed from the menu "Kernel-Change Kernel" to ```nosql```
#
# [REQ]:<https://docs.anaconda.com/miniconda/system-requirements/>
# [COMDS]:<https://docs.conda.io/projects/conda/en/stable/commands/index.html>
# [CSHT]:<https://docs.conda.io/projects/conda/en/stable/user-guide/cheatsheet.html>

# %%
# Verifiying all libraries are ok!
try:
    import pandas as pd
    import matplotlib.pyplot as plt
    import numpy as np
    
    print("Everything is fine, the libraries pandas, matplotlib and numpy are installed.")
except ImportError as e:
    print(f"Error: {e}")
# Out:
# Everything is fine, the libraries pandas, matplotlib and numpy are installed.

# %% [markdown]
# <a id="nb"></a>
#
# ## Jupiter Notebooks
#
# [**Jupyter Notebooks**][NB] is an open-source, interactive web application that allows you to create and share documents that contain live code, equations, visualizations, and narrative text. It is commonly used for data science, machine learning, and academic research.
#
# Some key features of Jupyter Notebooks are:
#
# * **Interactive Code:** You can write and execute code in various programming languages (such as Python, R, Julia, etc.) directly within the notebook.
#
#
# * **Data Visualization:** It supports visualizations with libraries like matplotlib, seaborn, and plotly, enabling you to create interactive and static plots.
#
#
# * **Markdown and Rich Text:** You can use Markdown to add descriptive text, including formatting, equations (using LaTeX), and images.
#
#
# * **Reproducible Research:** Jupyter Notebooks are great for documenting your code, results, and methodology, making it easier to share and reproduce research.
#
#
# * **Flexible Kernels:**You can use different programming languages (kernels) within a single notebook, depending on the installed kernels.
#
#
# [NB]:<https://jupyter.org>

# %% [markdown]
# <a id="md"></a>
# ## Markdown
#
# **Markdown** is a lightweight markup language that allows you to format text using plain text syntax. It is designed to be easy to read and write while providing a simple way to apply formatting like headings, bold text, lists, and links. Markdown is widely used for documentation, readme files, blogging, and in Jupyter Notebooks for adding rich text content alongside code.
#
# Here are some basic elements of Markdown:
#
# - **Headings:** Use # symbols to create headings.
# ```markdown
# # Heading 1
# ## Heading 2
# ### Heading 3
# ```
#
# - **Bold Text:** Wrap the text in double asterisks ```**``` or double underscores ```__```
#
# ```markdown
# **Bold Text** or __Bold Text__
# ```
#
# - **Italic Text:** Wrap the text in single asterisks ```*``` or single underscores```_```
#
# ```markdown
# *Italic Text* or _Italic Text_
# ```
#
# - **Lists:**
#
# - **Unordered** list: Use *, -, or + followed by a space.
#
# ```markdown
# * Item 1
# - Item 2
# ```
#
# - **Ordered** list: Use numbers followed by a period.
#
# ```markdown
# 1. First item
# 2. Second item
# ```
#
# - **Links:** Use square brackets for the link text and parentheses for the URL.
#
# ```markdown
# [OpenAI](https://www.openai.com)
# ```
#
# - **Images:** Similar to links, but with an exclamation mark at the beginning.
#
# ```markdown
# ![Image Alt Text](image_url)
# ```
#
# - **Code:** Inline code is wrapped in backticks `code` and code blocks are wrapped in triple backticks.
# - Inline:
#
# ```markdown
# `print("Hello")`
# ```
#
# -Block:
#
# ```markdown
# def greet():
#     print("Hello World")
# ```
#
# Blockquotes: Use the > symbol to create a blockquote.
# ```markdown
# > This is a quote.
# ```
#
# References:
#
# [Basic syntax][MD]
#
# [MD]:<https://www.markdownguide.org/basic-syntax/>

# %% [markdown]
# <a id="py"></a>
# # Python programming
#
# Given that Python is a popular language programming it is highly recommended to acquire at least basic Python skills to enable trying out and modifying code examples. There are many good books on the topic of programming, and if you have basic programming skills, it should be relatively simple to get started with Python by just following tutorials at [python.org](https://www.python.org).
#
# A specific module that is used frequently is the [NumPy](https://numpy.org) (numerical Python) module that, among other things, provides data types for vectors and matrices. It is also common to use [pandas](https://pandas.pydata.org) (Python Data Manipulation Library) to manipulate multidimensional data. Also Matplotlib, which is a popular plotting library for Python. It allows you to create static, animated, and interactive visualizations in Python.
#
#
# The following Python constructs are frequent:
#
#
# * Integer and floating point datatypes
#
#
# * Lists and dictionaries
#
#
# * Importing and using external packages
#
#
# * If-statements, for-loops, and while-loops
#
#
# * Defining and calling functions
#
#
# * Printing strings and numerical datatypes
#
#
# * Plotting data with matplotlib
#
#
# * Reading from and writing to files
#
#
#
#
# ## Referencias:
#
# * [**Python Tutor**][Tut-Python]
#
#
# * $W^3$Schools [Python Tutorial][W3-Python]
#
# [Tut-Python]: <https://pythontutor.com>
#
# [W3-Python]: <https://www.w3schools.com/python/default.asp>
#
#
# <p style="text-align:center">
#     <a href="https://pythonnumericalmethods.berkeley.edu/notebooks/Index.html" target="_blank">
#     <img src="figures/pythonProgrammingNumericalMethods_cover.jpg" width="50" align="right" />
#     </a>
# </p>
#
# * Python Programming And Numerical Methods: A Guide For Engineers And Scientists
# [Online Book][PYTHON] under the [MIT licence][MIT-LICENCE]
#
#
# [PYTHON]:<https://pythonnumericalmethods.berkeley.edu/notebooks/Index.html>
# [MIT-LICENCE]: <https://opensource.org/licenses/MIT>
#
#
# <p style="text-align:center">
#     <a href="http://jrjohansson.github.io/numericalpython.html" target="_blank">
#     <img src="figures/numericalpython-cover.jpg" width="50" align="right" />
#     </a>
# </p>
#
# * Numerical Python: A Practical Techniques Approach for Industry
# [Online Book][NUM-PYTHON] from GitHub
#
# [NUM-PYTHON]:<http://jrjohansson.github.io/numericalpython.html>

# %% [markdown]
# <a id=""></a>
